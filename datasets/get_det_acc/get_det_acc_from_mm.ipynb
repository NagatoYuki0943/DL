# %%
import os
import pickle
from pathlib import Path
from glob import glob
import yaml
from collections import defaultdict

# %%
label_path = Path("D:/ml/code/yolov5/data/cotton-classes16.yaml")

# %%
val_dir = Path("D:/ml/code/datasets/cotton-classes16/val/labels")
pkl_path = Path("D:/ml/code/mm/mmdetection/work_dirs/classes16/cascade-rcnn_convnext-t_fpn_3x_classes16_sgd_auto-scale-lr/unique_ids.pkl")

# %%
assert label_path.exists(), f"{label_path} not exists"
assert val_dir.exists(), f"{val_dir} not exists"
assert pkl_path.exists(), f"{pkl_path} not exists"

# %% [markdown]
# # load label name

# %%
with open(label_path, 'r', encoding='utf-8') as f:
    dataset = yaml.safe_load(f)
names = dataset["names"]
names
# Out:
# {0: 'cao_ling_chong',
#  1: 'hong_zhi_zhu',
#  2: 'ji_ma',
#  3: 'long_kui',
#  4: 'ma_chi_xian',
#  5: 'mian_hua_he_ban_bing',
#  6: 'mian_hua_huang_wei_bing',
#  7: 'mian_hua_lao_ye_huang_hua',
#  8: 'mian_hua_ye_pian_lao_hua',
#  9: 'mian_ling_chong',
#  10: 'mian_ya',
#  11: 'piao_chong',
#  12: 'shi_ya_ying',
#  13: 'tian_xuan_hua',
#  14: 'yan_fen_shi',
#  15: 'ye_xi_gua_miao'}

# %%
num_classes = len(names)
num_classes

# %% [markdown]
# # 创建id2txt的字典
#
# ```python
# {
#     0: ["pic1", "pic2", "pic3"...],
#     1: ["pic2", "pic3", "pic5"...],
#     ...
# }
# ```

# %%
val_id2stem = defaultdict(list)
pred_id2stem = defaultdict(list)
val_id2stem, pred_id2stem
# Out:
# (defaultdict(list, {}), defaultdict(list, {}))

# %% [markdown]
# # 读取txt中的数据

# %%
def get_txts_data(path: Path) -> dict[str, list[str]]:
    """获取txt中数据,按照行分割

    Args:
        path (Path): txt文件夹路径

    Returns:
        dict[str, list[str]]:
            {
                img1: [line1],
                img2: [line1, line2],
                ....
            }
    """
    val_txts = path.glob("*.txt")
    data = {}
    for txt in val_txts:
        stem = txt.stem
        with open(txt) as f:
            lines = f.read().splitlines()                   # splitlines可以去除单个空行
            lines = [line for line in lines if line != ""]  # 去除空行
        data[stem] = lines
    return data

# %%
val_data = get_txts_data(val_dir)
print(len(val_data.keys()))
k = list(val_data.keys())[0]
print(k, ":", val_data[k])
# Out:
# 398
# 20220711122406 : ['1 0.600446 0.493056 0.59871 0.820767']

# %% [markdown]
# # 获取 unique id

# %%
def get_txt_unique_ids(data: dict[str, list[str]]) -> dict[str, list[int]]:
    """获取每张图片中的类别id,去重

    Args:
        data (dict[str, list[str]]): get_txts_data 的返回值

    Returns:
        dict[str, list[int]]:
            {
                img1: [0],
                img2: [0, 1],
                ...
            }
    """
    unique_data = {}
    # key: filename
    # value: [line1, line2...]
    for stem, lines in data.items():
        # get line [0] label
        ids = [int(line.split(" ")[0]) for line in lines]
        # unique label
        unique_ids = sorted(set(ids))
        unique_data[stem] = unique_ids
    return unique_data

# %%
val_txt_unique_ids = get_txt_unique_ids(val_data)
print(len(val_txt_unique_ids.keys()))
k = list(val_txt_unique_ids.keys())[0]
print(k, ":", val_txt_unique_ids[k])
# Out:
# 398
# 20220711122406 : [1]

# %%
with open(pkl_path, mode="rb") as f:
    pred_txt_unique_ids = pickle.load(f)
print(len(pred_txt_unique_ids.keys()))
k = list(pred_txt_unique_ids.keys())[0]
print(k, ":", pred_txt_unique_ids[k])
# Out:
# 398
# 20220711122406 : [1, 5, 8, 9, 10]

# %% [markdown]
# # 将txt中的数据转移到id2stem中

# %%
val_id2stem[0], val_id2stem[1]
# Out:
# ([], [])

# %%
def txt_id2stem(txt_unique_ids: dict[str, list[int]], id2stem: dict[int, list[str]]):
    """将uniqueid中的图片数据放入

    Args:
        txt_unique_ids (dict[str, list[int]]): get_txt_unique_ids 的返回值
        id2stem (dict[int, list[str]]):
            {
                0: [img1],
                1: [img2, img4],
                ...
            }
    """
    # 清空id2txt中数组的内容
    for i in id2stem.values():
        i.clear()
    # stem: filename
    # unique_ids: [id0, id1...]
    for stem, unique_ids in txt_unique_ids.items():
        for unique_id in unique_ids:
            # {id0: [img1, img2...]}
            id2stem[unique_id].append(stem)

# %%
txt_id2stem(val_txt_unique_ids, val_id2stem)
val_id2stem[1]
# Out:
# ['20220711122406',
#  '20220711122529',
#  '20220711122538',
#  '20220711122912',
#  '20220711122916']

# %%
txt_id2stem(pred_txt_unique_ids, pred_id2stem)
pred_id2stem[1]
# Out:
# ['20220711122406',
#  '20220711122529',
#  '20220711122538',
#  '20220711122912',
#  '20220711122916',
#  'IMG_0923',
#  'IMG_1288',
#  'IMG_2315',
#  'IMG_3355']

# %%
for i in range(num_classes):
    print(len(val_id2stem[i]), len(pred_id2stem[i]))
# Out:
# 3 8
# 5 9
# 4 8
# 3 19
# 3 11
# 35 63
# 18 50
# 1 27
# 37 58
# 25 70
# 232 291
# 163 181
# 2 4
# 11 29
# 3 3
# 2 5

# %% [markdown]
# # 获取评估指标,每个类别和总的召回率,精确率

# %%
def get_metrics(val_id2stem: dict[int, list[str]], pred_id2stem: dict[int, list[str]], eps: float = 1e-8) -> tuple[dict, dict[int, dict]]:
    """获取每个类别和总的评估指标

    Args:
        val_id2stem (dict[int, list[str]]):  val
        pred_id2stem (dict[int, list[str]]): pred
        eps (float): 防止除零. Default 1e-8

    Returns:
        tuple[dict, dict[int, dict]]:
            dict:               总指标
            dict[int, dict]:    各类别指标
    """
    total_val = 0       # val total
    total_pred = 0      # pred total
    total_detect = 0    # detect total
    result_for_cls = {} # 每个类别准确率
    for i in range(num_classes):
        # set在这里不为去重,仅仅为了求交集,差集
        val_stem_for_single_id: set = set(val_id2stem[i])   # 单一类别val图片名字
        pred_stem_for_single_id: set = set(pred_id2stem[i]) # 单一类别pred图片名字

        num_val = len(val_stem_for_single_id)
        total_val += num_val
        num_pred = len(pred_stem_for_single_id)
        total_pred += num_pred

        # 检测到的图片名字
        detect      = val_stem_for_single_id.intersection(pred_stem_for_single_id)
        num_detect  = len(detect)
        total_detect += num_detect
        # 没有检测到图片名字
        not_detect  = val_stem_for_single_id.difference(pred_stem_for_single_id)
        # 过度检测到图片名字
        over_detect = pred_stem_for_single_id.difference(val_stem_for_single_id)

        recall = num_detect / (num_val + eps)
        precision = num_detect / (num_pred + eps)
        f1_score = (2 * recall * precision) / (recall + precision + eps)

        # 按照类别id保存
        result_for_cls[i] = {
            "num_val": num_val,
            "num_pred": num_pred,
            "num_detect": num_detect,
            "recall": recall,
            "precision": precision,
            "f1_score": f1_score,
            "detect": detect,
            "not_detect": not_detect,
            "over_detect": over_detect,
        }

    recall = total_detect / total_val
    precision = total_detect / total_pred
    f1_score = (2 * recall * precision) / (recall + precision+ eps)

    total_result = {
        "num_val": total_val,
        "num_pred": total_pred,
        "num_detect": total_detect,
        "recall": recall,
        "precision": precision,
        "f1_score": f1_score,
    }

    return total_result, result_for_cls

# %%
total_result, result_for_cls = get_metrics(val_id2stem, pred_id2stem)
total_result
# Out:
# {'num_val': 547,
#  'num_pred': 836,
#  'num_detect': 527,
#  'recall': 0.9634369287020109,
#  'precision': 0.6303827751196173}

# %%
result_for_cls
# Out:
# {0: {'num_val': 3,
#   'num_pred': 8,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.25,
#   'detect': {'IMG_1245', 'IMG_3348'},
#   'not_detect': {'IMG_2236'},
#   'over_detect': {'IMG_0051',
#    'IMG_1040',
#    'IMG_1076',
#    'IMG_2822',
#    'IMG_3026',
#    'IMG_9892'}},
#  1: {'num_val': 5,
#   'num_pred': 9,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 0.5555555555555556,
#   'detect': {'20220711122406',
#    '20220711122529',
#    '20220711122538',
#    '20220711122912',
#    '20220711122916'},
#   'not_detect': set(),
#   'over_detect': {'IMG_0923', 'IMG_1288', 'IMG_2315', 'IMG_3355'}},
#  2: {'num_val': 4,
#   'num_pred': 8,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.5,
#   'detect': {'DSC02069', 'DSC02071', 'DSC02095', 'IMG_9904'},
#   'not_detect': set(),
#   'over_detect': {'IMG_0011', 'IMG_1023', 'IMG_1113', 'IMG_9801'}},
#  3: {'num_val': 3,
#   'num_pred': 19,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 0.15789473684210525,
#   'detect': {'IMG_0958', 'IMG_9440', 'longkui1'},
#   'not_detect': set(),
#   'over_detect': {'DSC02069',
#    'IMG_0334',
#    'IMG_0365',
#    'IMG_0490',
#    'IMG_0733',
#    'IMG_0744',
#    'IMG_0869',
#    'IMG_0871',
#    'IMG_0917',
#    'IMG_0933',
#    'IMG_0934',
#    'IMG_1023',
#    'IMG_1180',
#    'IMG_1492',
#    'IMG_1518',
#    'IMG_9892'}},
#  4: {'num_val': 3,
#   'num_pred': 11,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.18181818181818182,
#   'detect': {'IMG_0958', 'IMG_1180'},
#   'not_detect': {'IMG_0744'},
#   'over_detect': {'IMG_0733',
#    'IMG_0771',
#    'IMG_0866',
#    'IMG_0933',
#    'IMG_0934',
#    'IMG_1087',
#    'IMG_1518',
#    'IMG_20220803_113241',
#    'longkui1'}},
#  5: {'num_val': 35,
#   'num_pred': 63,
#   'num_detect': 29,
#   'recall': 0.8285714285714286,
#   'precision': 0.4603174603174603,
#   'detect': {'IMG_0105',
#    'IMG_0142',
#    'IMG_0172',
#    'IMG_0490',
#    'IMG_0531',
#    'IMG_0585',
#    'IMG_0599-1',
#    'IMG_0601-1',
#    'IMG_0635',
#    'IMG_0649',
#    'IMG_0749',
#    'IMG_0823',
#    'IMG_1174',
#    'IMG_1323_1881',
#    'IMG_2111',
#    'IMG_3041',
#    'IMG_3281',
#    'IMG_8608',
#    'IMG_8714',
#    'IMG_9017',
#    'IMG_9221',
#    'IMG_9364',
#    'IMG_9369',
#    'IMG_9370',
#    'IMG_9373',
#    'IMG_9407',
#    'IMG_9491',
#    'IMG_9791',
#    'IMG_9963'},
#   'not_detect': {'IMG_0100',
#    'IMG_0800',
#    'IMG_8739',
#    'IMG_9244',
#    'IMG_9417',
#    'IMG_9437'},
#   'over_detect': {'20220711122406',
#    'IMG_0236_91',
#    'IMG_0420',
#    'IMG_0735',
#    'IMG_0767',
#    'IMG_0825',
#    'IMG_0903',
#    'IMG_0907',
#    'IMG_0925',
#    'IMG_1034',
#    'IMG_1419',
#    'IMG_1502',
#    'IMG_1518',
#    'IMG_2145',
#    'IMG_2149',
#    'IMG_2184',
#    'IMG_3138',
#    'IMG_3176',
#    'IMG_3355',
#    'IMG_3419',
#    'IMG_8581',
#    'IMG_8586',
#    'IMG_9130',
#    'IMG_9152',
#    'IMG_9183',
#    'IMG_9199',
#    'IMG_9289',
#    'IMG_9319',
#    'IMG_9323',
#    'IMG_9393',
#    'IMG_9555',
#    'IMG_9624',
#    'IMG_9869',
#    'IMG_9992'}},
#  6: {'num_val': 18,
#   'num_pred': 50,
#   'num_detect': 18,
#   'recall': 1.0,
#   'precision': 0.36,
#   'detect': {'IMG_20220731_175803',
#    'IMG_20220803_113241',
#    'IMG_20220803_113301',
#    'IMG_20220803_113351',
#    'IMG_20220803_113543',
#    'IMG_20220803_115032',
#    'IMG_20220803_115050',
#    'IMG_2138',
#    'IMG_2140',
#    'IMG_2145',
#    'IMG_2149',
#    'IMG_2182_11',
#    'IMG_2184',
#    'IMG_2993_11',
#    'IMG_2995_51',
#    'IMG_3490',
#    'IMG_8532',
#    'IMG_8540'},
#   'not_detect': set(),
#   'over_detect': {'IMG_0235_1',
#    'IMG_0385',
#    'IMG_0723',
#    'IMG_0735',
#    'IMG_0771',
#    'IMG_0903',
#    'IMG_0923',
#    'IMG_0925',
#    'IMG_1098',
#    'IMG_1288',
#    'IMG_1518',
#    'IMG_2219',
#    'IMG_2315',
#    'IMG_2487',
#    'IMG_3041',
#    'IMG_3115',
#    'IMG_3171',
#    'IMG_3176',
#    'IMG_3189',
#    'IMG_3354',
#    'IMG_3494',
#    'IMG_8672',
#    'IMG_8896',
#    'IMG_9015',
#    'IMG_9289',
#    'IMG_9322',
#    'IMG_9323',
#    'IMG_9370',
#    'IMG_9516',
#    'IMG_9578',
#    'IMG_9725',
#    'IMG_9805'}},
#  7: {'num_val': 1,
#   'num_pred': 27,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'detect': set(),
#   'not_detect': {'IMG_2315'},
#   'over_detect': {'IMG_0412',
#    'IMG_0630',
#    'IMG_0723',
#    'IMG_0735',
#    'IMG_0869',
#    'IMG_0903',
#    'IMG_0923',
#    'IMG_0925',
#    'IMG_0958',
#    'IMG_1518',
#    'IMG_20220803_113301',
#    'IMG_2140',
#    'IMG_2145',
#    'IMG_2149',
#    'IMG_2487',
#    'IMG_2995_51',
#    'IMG_3041',
#    'IMG_3115',
#    'IMG_3171',
#    'IMG_3176',
#    'IMG_3189',
#    'IMG_3354',
#    'IMG_3490',
#    'IMG_8532',
#    'IMG_8540',
#    'IMG_9322',
#    'IMG_9323'}},
#  8: {'num_val': 37,
#   'num_pred': 58,
#   'num_detect': 36,
#   'recall': 0.972972972972973,
#   'precision': 0.6206896551724138,
#   'detect': {'IMG_0412',
#    'IMG_0630',
#    'IMG_0635',
#    'IMG_0723',
#    'IMG_0735',
#    'IMG_0738',
#    'IMG_0767',
#    'IMG_0771',
#    'IMG_0823',
#    'IMG_0825',
#    'IMG_0838',
#    'IMG_0858',
#    'IMG_0869',
#    'IMG_0903',
#    'IMG_0923',
#    'IMG_0925',
#    'IMG_1098',
#    'IMG_1288',
#    'IMG_1518',
#    'IMG_2487',
#    'IMG_3041',
#    'IMG_3115',
#    'IMG_3129',
#    'IMG_3138',
#    'IMG_3171',
#    'IMG_3176',
#    'IMG_3189',
#    'IMG_3354',
#    'IMG_3494',
#    'IMG_8896',
#    'IMG_9015',
#    'IMG_9017',
#    'IMG_9289',
#    'IMG_9322',
#    'IMG_9323',
#    'IMG_9516'},
#   'not_detect': {'IMG_0334'},
#   'over_detect': {'20220711122406',
#    '20220711122912',
#    'IMG_0385',
#    'IMG_0554',
#    'IMG_0585',
#    'IMG_0778',
#    'IMG_0832',
#    'IMG_0866',
#    'IMG_0958',
#    'IMG_2145',
#    'IMG_2149',
#    'IMG_2993_11',
#    'IMG_2995_51',
#    'IMG_3355',
#    'IMG_3490',
#    'IMG_8886',
#    'IMG_9145',
#    'IMG_9298',
#    'IMG_9299',
#    'IMG_9448',
#    'IMG_9725',
#    'IMG_9797'}},
#  9: {'num_val': 25,
#   'num_pred': 70,
#   'num_detect': 23,
#   'recall': 0.92,
#   'precision': 0.32857142857142857,
#   'detect': {'IMG_0011',
#    'IMG_0490',
#    'IMG_0493',
#    'IMG_0512',
#    'IMG_0531',
#    'IMG_0554',
#    'IMG_0585',
#    'IMG_0611',
#    'IMG_0735',
#    'IMG_0800',
#    'IMG_1288',
#    'IMG_2770',
#    'IMG_3041',
#    'IMG_3115',
#    'IMG_3138',
#    'IMG_3176',
#    'IMG_3189',
#    'IMG_8581',
#    'IMG_8956',
#    'IMG_9015',
#    'IMG_9145',
#    'IMG_9578',
#    'IMG_9805'},
#   'not_detect': {'IMG_1076', 'IMG_2027'},
#   'over_detect': {'20220711122406',
#    'IMG_0093',
#    'IMG_0105',
#    'IMG_0147',
#    'IMG_0320',
#    'IMG_0334',
#    'IMG_0420',
#    'IMG_0599-1',
#    'IMG_0644',
#    'IMG_0649',
#    'IMG_0825',
#    'IMG_0871',
#    'IMG_0917',
#    'IMG_0925',
#    'IMG_0933',
#    'IMG_1016',
#    'IMG_1040',
#    'IMG_1113',
#    'IMG_1179',
#    'IMG_1196',
#    'IMG_1245',
#    'IMG_1351',
#    'IMG_1518',
#    'IMG_20220731_175803',
#    'IMG_2048_21',
#    'IMG_2149',
#    'IMG_2487',
#    'IMG_3129',
#    'IMG_3370',
#    'IMG_8896',
#    'IMG_9119',
#    'IMG_9179',
#    'IMG_9298',
#    'IMG_9393',
#    'IMG_9396',
#    'IMG_9417',
#    'IMG_9440',
#    'IMG_9448',
#    'IMG_9518',
#    'IMG_9534',
#    'IMG_9710',
#    'IMG_9715',
#    'IMG_9725',
#    'IMG_9869',
#    'IMG_9911',
#    'IMG_9942',
#    'IMG_9992'}},
#  10: {'num_val': 232,
#   'num_pred': 291,
#   'num_detect': 231,
#   'recall': 0.9956896551724138,
#   'precision': 0.7938144329896907,
#   'detect': {'DSC02006',
#    'DSC02287',
#    'DSC02303',
#    'DSC02329',
#    'DSC02331',
#    'DSC02334',
#    'DSC02339',
#    'DSC02432',
#    'DSC02434',
#    'DSC02449',
#    'DSC02469',
#    'IMG_0051',
#    'IMG_0086',
#    'IMG_0117',
#    'IMG_0144',
#    'IMG_0147',
#    'IMG_0157',
#    'IMG_0298',
#    'IMG_0320',
#    'IMG_0324',
#    'IMG_0331-1',
#    'IMG_0365',
#    'IMG_0374-1',
#    'IMG_0376',
#    'IMG_0380',
#    'IMG_0385',
#    'IMG_0390',
#    'IMG_0419',
#    'IMG_0420',
#    'IMG_0434',
#    'IMG_0490',
#    'IMG_0512',
#    'IMG_0531',
#    'IMG_0537',
#    'IMG_0554',
#    'IMG_0602',
#    'IMG_0630',
#    'IMG_0635',
#    'IMG_0638',
#    'IMG_0644',
#    'IMG_0646',
#    'IMG_0649',
#    'IMG_0687',
#    'IMG_0735',
#    'IMG_0749',
#    'IMG_0771',
#    'IMG_0773',
#    'IMG_0775',
#    'IMG_0778',
#    'IMG_0798',
#    'IMG_0800',
#    'IMG_0823',
#    'IMG_0832',
#    'IMG_0858',
#    'IMG_0869',
#    'IMG_0907',
#    'IMG_0925',
#    'IMG_0987',
#    'IMG_1010',
#    'IMG_1016',
#    'IMG_1022',
#    'IMG_1023',
#    'IMG_1039',
#    'IMG_1040',
#    'IMG_1044',
#    'IMG_1062',
#    'IMG_1098',
#    'IMG_1113',
#    'IMG_1117',
#    'IMG_1136',
#    'IMG_1168',
#    'IMG_1204',
#    'IMG_1269',
#    'IMG_1323_1081',
#    'IMG_1323_1631',
#    'IMG_1323_1881',
#    'IMG_1323_2171',
#    'IMG_1323_2821',
#    'IMG_1323_3001',
#    'IMG_1323_41',
#    'IMG_1323_511',
#    'IMG_1323_611',
#    'IMG_1343',
#    'IMG_1351',
#    'IMG_1433',
#    'IMG_1497',
#    'IMG_20220709_131630',
#    'IMG_2048_21',
#    'IMG_2052',
#    'IMG_2054',
#    'IMG_2098',
#    'IMG_2101',
#    'IMG_2104',
#    'IMG_2111',
#    'IMG_2129',
#    'IMG_2131',
#    'IMG_2175_1',
#    'IMG_2219',
#    'IMG_2236',
#    'IMG_2247',
#    'IMG_2250',
#    'IMG_2315',
#    'IMG_2381',
#    'IMG_2401',
#    'IMG_2512',
#    'IMG_2594',
#    'IMG_2597',
#    'IMG_2610',
#    'IMG_2618',
#    'IMG_2630',
#    'IMG_2648',
#    'IMG_2662',
#    'IMG_2727',
#    'IMG_2744',
#    'IMG_2761',
#    'IMG_2881',
#    'IMG_3013',
#    'IMG_3026',
#    'IMG_3036',
#    'IMG_3041',
#    'IMG_3076',
#    'IMG_3108',
#    'IMG_3109',
#    'IMG_3129',
#    'IMG_3176',
#    'IMG_3228',
#    'IMG_3245',
#    'IMG_3248',
#    'IMG_3262',
#    'IMG_3266',
#    'IMG_3284',
#    'IMG_3355',
#    'IMG_3368',
#    'IMG_3370',
#    'IMG_3419',
#    'IMG_3490',
#    'IMG_8563',
#    'IMG_8564',
#    'IMG_8577',
#    'IMG_8581',
#    'IMG_8586',
#    'IMG_8600',
#    'IMG_8603',
#    'IMG_8608',
#    'IMG_8609',
#    'IMG_8621',
#    'IMG_8634',
#    'IMG_8639',
#    'IMG_8671',
#    'IMG_8672',
#    'IMG_8713',
#    'IMG_8731',
#    'IMG_8739',
#    'IMG_8762',
#    'IMG_8765',
#    'IMG_8766',
#    'IMG_8769',
#    'IMG_8789',
#    'IMG_8796',
#    'IMG_8808',
#    'IMG_8830',
#    'IMG_8841',
#    'IMG_8865',
#    'IMG_8886',
#    'IMG_8888',
#    'IMG_8931',
#    'IMG_8956',
#    'IMG_8980',
#    'IMG_8986',
#    'IMG_9015',
#    'IMG_9017',
#    'IMG_9046',
#    'IMG_9068',
#    'IMG_9088',
#    'IMG_9102',
#    'IMG_9119',
#    'IMG_9130',
#    'IMG_9138',
#    'IMG_9145',
#    'IMG_9152',
#    'IMG_9175',
#    'IMG_9179',
#    'IMG_9183',
#    'IMG_9185',
#    'IMG_9192',
#    'IMG_9199',
#    'IMG_9200',
#    'IMG_9202',
#    'IMG_9221',
#    'IMG_9244',
#    'IMG_9289',
#    'IMG_9298',
#    'IMG_9299',
#    'IMG_9319',
#    'IMG_9322',
#    'IMG_9323',
#    'IMG_9341',
#    'IMG_9360',
#    'IMG_9364',
#    'IMG_9393',
#    'IMG_9396',
#    'IMG_9397',
#    'IMG_9402',
#    'IMG_9417',
#    'IMG_9440',
#    'IMG_9448',
#    'IMG_9490',
#    'IMG_9491',
#    'IMG_9510',
#    'IMG_9516',
#    'IMG_9518',
#    'IMG_9555',
#    'IMG_9699',
#    'IMG_9710',
#    'IMG_9711',
#    'IMG_9713',
#    'IMG_9715',
#    'IMG_9716',
#    'IMG_9725',
#    'IMG_9791',
#    'IMG_9797',
#    'IMG_9799',
#    'IMG_9801',
#    'IMG_9805',
#    'IMG_9892',
#    'IMG_9904',
#    'IMG_9911',
#    'IMG_9920',
#    'IMG_9942',
#    'IMG_9945',
#    'IMG_9992'},
#   'not_detect': {'IMG_9758'},
#   'over_detect': {'20220711122406',
#    '20220711122529',
#    '20220711122538',
#    '20220711122912',
#    '20220711122916',
#    'DSC02243',
#    'DSC02257',
#    'IMG_0093',
#    'IMG_0235_1',
#    'IMG_0493',
#    'IMG_0585',
#    'IMG_0723',
#    'IMG_0733',
#    'IMG_0738',
#    'IMG_0744',
#    'IMG_0767',
#    'IMG_0825',
#    'IMG_0866',
#    'IMG_0917',
#    'IMG_0923',
#    'IMG_0958',
#    'IMG_1087',
#    'IMG_1153',
#    'IMG_1163',
#    'IMG_1166',
#    'IMG_1174',
#    'IMG_1315',
#    'IMG_1334',
#    'IMG_1502',
#    'IMG_20220731_175803',
#    'IMG_2138',
#    'IMG_2140',
#    'IMG_2145',
#    'IMG_2182_11',
#    'IMG_2452',
#    'IMG_2799',
#    'IMG_2815',
#    'IMG_2822',
#    'IMG_2964_1',
#    'IMG_3115',
#    'IMG_3171',
#    'IMG_3189',
#    'IMG_3348',
#    'IMG_3361',
#    'IMG_3494',
#    'IMG_8714',
#    'IMG_8728',
#    'IMG_8896',
#    'IMG_9107',
#    'IMG_9111',
#    'IMG_9263',
#    'IMG_9369',
#    'IMG_9370',
#    'IMG_9373',
#    'IMG_9379',
#    'IMG_9527',
#    'IMG_9578',
#    'IMG_9869',
#    'IMG_9949',
#    'IMG_9963'}},
#  11: {'num_val': 163,
#   'num_pred': 181,
#   'num_detect': 158,
#   'recall': 0.9693251533742331,
#   'precision': 0.8729281767955801,
#   'detect': {'IMG_0051',
#    'IMG_0086',
#    'IMG_0093',
#    'IMG_0100',
#    'IMG_0105',
#    'IMG_0142',
#    'IMG_0158',
#    'IMG_0172',
#    'IMG_0236_91',
#    'IMG_0331-1',
#    'IMG_0368',
#    'IMG_0374-1',
#    'IMG_0434',
#    'IMG_0531',
#    'IMG_0585',
#    'IMG_0635',
#    'IMG_0649',
#    'IMG_0687',
#    'IMG_0703',
#    'IMG_0749',
#    'IMG_0917',
#    'IMG_0995',
#    'IMG_1034',
#    'IMG_1062',
#    'IMG_1113',
#    'IMG_1117',
#    'IMG_1129',
#    'IMG_1132',
#    'IMG_1136',
#    'IMG_1153',
#    'IMG_1163',
#    'IMG_1166',
#    'IMG_1174',
#    'IMG_1179',
#    'IMG_1296_261',
#    'IMG_1296_341',
#    'IMG_1296_81',
#    'IMG_1306',
#    'IMG_1315',
#    'IMG_1334',
#    'IMG_1412',
#    'IMG_1417',
#    'IMG_1419',
#    'IMG_1433',
#    'IMG_1435',
#    'IMG_1492',
#    'IMG_1497',
#    'IMG_1502',
#    'IMG_2078',
#    'IMG_2098',
#    'IMG_2101',
#    'IMG_2104',
#    'IMG_2129',
#    'IMG_2237',
#    'IMG_2247',
#    'IMG_2250',
#    'IMG_2370',
#    'IMG_2381',
#    'IMG_2417',
#    'IMG_2439',
#    'IMG_2452',
#    'IMG_2503',
#    'IMG_2512',
#    'IMG_2530',
#    'IMG_2594',
#    'IMG_2597',
#    'IMG_2610',
#    'IMG_2648',
#    'IMG_2662',
#    'IMG_2707',
#    'IMG_2744',
#    'IMG_2749',
#    'IMG_2763',
#    'IMG_2793',
#    'IMG_2799',
#    'IMG_2815',
#    'IMG_2881',
#    'IMG_2955',
#    'IMG_2964_1',
#    'IMG_2966',
#    'IMG_3013',
#    'IMG_3036',
#    'IMG_3070',
#    'IMG_3076',
#    'IMG_3108',
#    'IMG_3109',
#    'IMG_3136',
#    'IMG_3204_161',
#    'IMG_3212',
#    'IMG_3220',
#    'IMG_3228',
#    'IMG_3252',
#    'IMG_3254',
#    'IMG_3274',
#    'IMG_3284',
#    'IMG_3295',
#    'IMG_3361',
#    'IMG_3368',
#    'IMG_3419',
#    'IMG_3443',
#    'IMG_3465',
#    'IMG_8703',
#    'IMG_8714',
#    'IMG_8728',
#    'IMG_8761',
#    'IMG_8769',
#    'IMG_8789',
#    'IMG_8841',
#    'IMG_8956',
#    'IMG_9040',
#    'IMG_9046',
#    'IMG_9088',
#    'IMG_9102',
#    'IMG_9107',
#    'IMG_9111',
#    'IMG_9179',
#    'IMG_9180',
#    'IMG_9183',
#    'IMG_9185',
#    'IMG_9192',
#    'IMG_9200',
#    'IMG_9221',
#    'IMG_9238',
#    'IMG_9244',
#    'IMG_9259',
#    'IMG_9263',
#    'IMG_9309',
#    'IMG_9313',
#    'IMG_9369',
#    'IMG_9370',
#    'IMG_9373',
#    'IMG_9379',
#    'IMG_9393',
#    'IMG_9396',
#    'IMG_9397',
#    'IMG_9402',
#    'IMG_9407',
#    'IMG_9437',
#    'IMG_9440',
#    'IMG_9490',
#    'IMG_9506',
#    'IMG_9518',
#    'IMG_9527',
#    'IMG_9529',
#    'IMG_9534',
#    'IMG_9613',
#    'IMG_9624',
#    'IMG_9699',
#    'IMG_9710',
#    'IMG_9713',
#    'IMG_9805',
#    'IMG_9844',
#    'IMG_9869',
#    'IMG_9892',
#    'IMG_9920',
#    'IMG_9945',
#    'IMG_9949',
#    'IMG_9963'},
#   'not_detect': {'IMG_0235_1', 'IMG_8830', 'IMG_9341', 'IMG_9417', 'IMG_9516'},
#   'over_detect': {'IMG_0599-1',
#    'IMG_0646',
#    'IMG_0735',
#    'IMG_0903',
#    'IMG_1076',
#    'IMG_1245',
#    'IMG_1269',
#    'IMG_1323_41',
#    'IMG_1351',
#    'IMG_2027',
#    'IMG_2727',
#    'IMG_3115',
#    'IMG_3245',
#    'IMG_3370',
#    'IMG_8586',
#    'IMG_8600',
#    'IMG_9298',
#    'IMG_9510',
#    'IMG_9715',
#    'IMG_9716',
#    'IMG_9791',
#    'IMG_9799',
#    'IMG_9911'}},
#  12: {'num_val': 2,
#   'num_pred': 4,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 0.5,
#   'detect': {'IMG_2389', 'IMG_2822'},
#   'not_detect': set(),
#   'over_detect': {'IMG_1245', 'IMG_2503'}},
#  13: {'num_val': 11,
#   'num_pred': 29,
#   'num_detect': 10,
#   'recall': 0.9090909090909091,
#   'precision': 0.3448275862068966,
#   'detect': {'IMG_0353',
#    'IMG_0733',
#    'IMG_0871',
#    'IMG_0933',
#    'IMG_0934',
#    'IMG_1087',
#    'IMG_1196',
#    'IMG_1204',
#    'IMG_1243',
#    'IMG_1310'},
#   'not_detect': {'IMG_0869'},
#   'over_detect': {'IMG_0320',
#    'IMG_0324',
#    'IMG_0334',
#    'IMG_0744',
#    'IMG_0866',
#    'IMG_0917',
#    'IMG_1023',
#    'IMG_1179',
#    'IMG_1180',
#    'IMG_1323_41',
#    'IMG_1412',
#    'IMG_1492',
#    'IMG_1518',
#    'IMG_8769',
#    'IMG_9221',
#    'IMG_9440',
#    'IMG_9758',
#    'IMG_9904',
#    'IMG_9945'}},
#  14: {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 1.0,
#   'detect': {'DSC02243', 'DSC02257', 'DSC02401'},
#   'not_detect': set(),
#   'over_detect': set()},
#  15: {'num_val': 2,
#   'num_pred': 5,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 0.2,
#   'detect': {'IMG_0866'},
#   'not_detect': {'IMG_1518'},
#   'over_detect': {'IMG_0733', 'IMG_0933', 'IMG_0934', 'IMG_1180'}}}

# %% [markdown]
# # label name to data

# %%
name2acc = {}
for name, acc_cls in zip(names.values(), result_for_cls.values()):
    name2acc[name] = {
        "num_val": acc_cls["num_val"],
        "num_pred": acc_cls["num_pred"],
        "num_detect": acc_cls["num_detect"],
        "recall": acc_cls["recall"],
        "precision": acc_cls["precision"],
        "f1_score": acc_cls["f1_score"],
    }
name2acc
# Out:
# {'cao_ling_chong': {'num_val': 3,
#   'num_pred': 8,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.25},
#  'hong_zhi_zhu': {'num_val': 5,
#   'num_pred': 9,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 0.5555555555555556},
#  'ji_ma': {'num_val': 4,
#   'num_pred': 8,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.5},
#  'long_kui': {'num_val': 3,
#   'num_pred': 19,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 0.15789473684210525},
#  'ma_chi_xian': {'num_val': 3,
#   'num_pred': 11,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.18181818181818182},
#  'mian_hua_he_ban_bing': {'num_val': 35,
#   'num_pred': 63,
#   'num_detect': 29,
#   'recall': 0.8285714285714286,
#   'precision': 0.4603174603174603},
#  'mian_hua_huang_wei_bing': {'num_val': 18,
#   'num_pred': 50,
#   'num_detect': 18,
#   'recall': 1.0,
#   'precision': 0.36},
#  'mian_hua_lao_ye_huang_hua': {'num_val': 1,
#   'num_pred': 27,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0},
#  'mian_hua_ye_pian_lao_hua': {'num_val': 37,
#   'num_pred': 58,
#   'num_detect': 36,
#   'recall': 0.972972972972973,
#   'precision': 0.6206896551724138},
#  'mian_ling_chong': {'num_val': 25,
#   'num_pred': 70,
#   'num_detect': 23,
#   'recall': 0.92,
#   'precision': 0.32857142857142857},
#  'mian_ya': {'num_val': 232,
#   'num_pred': 291,
#   'num_detect': 231,
#   'recall': 0.9956896551724138,
#   'precision': 0.7938144329896907},
#  'piao_chong': {'num_val': 163,
#   'num_pred': 181,
#   'num_detect': 158,
#   'recall': 0.9693251533742331,
#   'precision': 0.8729281767955801},
#  'shi_ya_ying': {'num_val': 2,
#   'num_pred': 4,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 0.5},
#  'tian_xuan_hua': {'num_val': 11,
#   'num_pred': 29,
#   'num_detect': 10,
#   'recall': 0.9090909090909091,
#   'precision': 0.3448275862068966},
#  'yan_fen_shi': {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 1.0},
#  'ye_xi_gua_miao': {'num_val': 2,
#   'num_pred': 5,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 0.2}}

# %%
total_result
# Out:
# {'num_val': 547,
#  'num_pred': 836,
#  'num_detect': 527,
#  'recall': 0.9634369287020109,
#  'precision': 0.6303827751196173}

# %%
name2acc["total"] = total_result

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(name2acc, index=["num_val", "num_pred", "num_detect", "recall", "precision", "f1_score"]).T
df
# Out:
#                            num_val  num_pred  num_detect    recall  precision
# cao_ling_chong                 3.0       8.0         2.0  0.666667   0.250000
# hong_zhi_zhu                   5.0       9.0         5.0  1.000000   0.555556
# ji_ma                          4.0       8.0         4.0  1.000000   0.500000
# long_kui                       3.0      19.0         3.0  1.000000   0.157895
# ma_chi_xian                    3.0      11.0         2.0  0.666667   0.181818
# mian_hua_he_ban_bing          35.0      63.0        29.0  0.828571   0.460317
# mian_hua_huang_wei_bing       18.0      50.0        18.0  1.000000   0.360000
# mian_hua_lao_ye_huang_hua      1.0      27.0         0.0  0.000000   0.000000
# mian_hua_ye_pian_lao_hua      37.0      58.0        36.0  0.972973   0.620690
# mian_ling_chong               25.0      70.0        23.0  0.920000   0.328571
# mian_ya                      232.0     291.0       231.0  0.995690   0.793814
# piao_chong                   163.0     181.0       158.0  0.969325   0.872928
# shi_ya_ying                    2.0       4.0         2.0  1.000000   0.500000
# tian_xuan_hua                 11.0      29.0        10.0  0.909091   0.344828
# yan_fen_shi                    3.0       3.0         3.0  1.000000   1.000000
# ye_xi_gua_miao                 2.0       5.0         1.0  0.500000   0.200000
# total                        547.0     836.0       527.0  0.963437   0.630383

# %%
df.to_excel("result.xlsx")

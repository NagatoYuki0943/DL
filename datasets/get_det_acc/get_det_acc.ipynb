# %%
from pathlib import Path
import pickle
import yaml
from collections import defaultdict

# %%
num_classes = 80
label_path = Path("D:/ml/code/yolov5/data/coco128.yaml")

# %%
val_dir = Path("D:/ml/code/datasets/coco128/labels/train2017")
pred_dir = Path("D:/ml/code/yolov5/runs/detect/coco128/yolov5s/labels")

# %%
assert label_path.exists(), f"{label_path} not exists"
assert val_dir.exists(), f"{val_dir} not exists"
assert pred_dir.exists(), f"{pred_dir} not exists"

# %% [markdown]
# # 创建id2txt的字典
#
# ```python
# {
#     0: ["pic1", "pic2", "pic3"...],
#     1: ["pic2", "pic3", "pic5"...],
#     ...
# }
# ```

# %%
val_id2stem = defaultdict(list)
pred_id2stem = defaultdict(list)
val_id2stem, pred_id2stem
# Out:
# (defaultdict(list, {}), defaultdict(list, {}))

# %% [markdown]
# # 读取txt中的数据

# %%
def get_txts_data(path: Path) -> dict[str, list[str]]:
    """获取txt中数据,按照行分割

    Args:
        path (Path): txt文件夹路径

    Returns:
        dict[str, list[str]]:
            {
                img1: [line1],
                img2: [line1, line2],
                ....
            }
    """
    val_txts = path.glob("*.txt")
    data = {}
    for txt in val_txts:
        stem = txt.stem
        with open(txt) as f:
            lines = f.read().splitlines()                   # splitlines可以去除单个空行
            lines = [line for line in lines if line != ""]  # 去除空行
        data[stem] = lines
    return data

# %%
val_data = get_txts_data(val_dir)
print(len(val_data.keys()))
k = list(val_data.keys())[0]
print(k, ":", val_data[k])
# Out:
# 128
# 000000000009 : ['45 0.479492 0.688771 0.955609 0.5955', '45 0.736516 0.247188 0.498875 0.476417', '50 0.637063 0.732938 0.494125 0.510583', '45 0.339438 0.418896 0.678875 0.7815', '49 0.646836 0.132552 0.118047 0.096937', '49 0.773148 0.129802 0.090734 0.097229', '49 0.668297 0.226906 0.131281 0.146896', '49 0.642859 0.079219 0.148063 0.148062']

# %%
pred_data = get_txts_data(pred_dir)
print(len(pred_data.keys()))
k = list(pred_data.keys())[0]
print(k, ":", pred_data[k])
# Out:
# 126
# 000000000009 : ['60 0.486719 0.50625 0.973437 0.9875 0.27229', '50 0.589063 0.928125 0.15625 0.14375 0.336526', '45 0.642187 0.728125 0.503125 0.53125 0.338169', '50 0.647656 0.736458 0.495313 0.527083 0.507882', '45 0.75625 0.248958 0.453125 0.497917 0.776129']

# %% [markdown]
# # 获取 unique id

# %%
def get_txt_unique_ids(data: dict[str, list[str]]) -> dict[str, list[int]]:
    """获取每张图片中的类别id,去重

    Args:
        data (dict[str, list[str]]): get_txts_data 的返回值

    Returns:
        dict[str, list[int]]:
            {
                img1: [0],
                img2: [0, 1],
                ...
            }
    """
    unique_data = {}
    # key: filename
    # value: [line1, line2...]
    for stem, lines in data.items():
        # get line [0] label
        ids = [int(line.split(" ")[0]) for line in lines]
        # unique label
        unique_ids = sorted(set(ids))
        unique_data[stem] = unique_ids
    return unique_data

# %%
val_txt_unique_ids = get_txt_unique_ids(val_data)
print(len(val_txt_unique_ids.keys()))
k = list(val_txt_unique_ids.keys())[0]
print(k, ":", val_txt_unique_ids[k])
# Out:
# 128
# 000000000009 : [45, 49, 50]

# %%
pred_txt_unique_ids = get_txt_unique_ids(pred_data)
print(len(pred_txt_unique_ids.keys()))
k = list(pred_txt_unique_ids.keys())[0]
print(k, ":", pred_txt_unique_ids[k])
# Out:
# 126
# 000000000009 : [45, 50, 60]

# %% [markdown]
# # 将txt中的数据转移到id2stem中

# %%
val_id2stem[0], val_id2stem[1]
# Out:
# ([], [])

# %%
def txt_id2stem(txt_unique_ids: dict[str, list[int]], id2stem: dict[int, list[str]]):
    """将uniqueid中的图片数据放入

    Args:
        txt_unique_ids (dict[str, list[int]]): get_txt_unique_ids 的返回值
        id2stem (dict[int, list[str]]):
            {
                0: [img1],
                1: [img2, img4],
                ...
            }
    """
    # 清空id2txt中数组的内容
    for i in id2stem.values():
        i.clear()
    # stem: filename
    # unique_ids: [id0, id1...]
    for stem, unique_ids in txt_unique_ids.items():
        for unique_id in unique_ids:
            # {id0: [img1, img2...]}
            id2stem[unique_id].append(stem)

# %%
txt_id2stem(val_txt_unique_ids, val_id2stem)
val_id2stem[1]
# Out:
# ['000000000074', '000000000531', '000000000641']

# %%
txt_id2stem(pred_txt_unique_ids, pred_id2stem)
pred_id2stem[1]
# Out:
# ['000000000074', '000000000086', '000000000641']

# %%
for i in range(num_classes):
    print(len(val_id2stem[i]), len(pred_id2stem[i]))
# Out:
# 61 62
# 3 3
# 12 10
# 4 4
# 5 5
# 5 5
# 3 2
# 5 4
# 2 1
# 4 2
# 0 0
# 2 2
# 0 0
# 5 4
# 2 2
# 4 5
# 9 7
# 1 1
# 0 0
# 0 0
# 4 4
# 1 1
# 2 2
# 4 4
# 4 4
# 4 4
# 9 3
# 6 4
# 2 2
# 5 5
# 1 2
# 2 1
# 6 4
# 2 2
# 4 3
# 4 4
# 3 2
# 0 0
# 5 5
# 6 8
# 5 6
# 10 9
# 6 3
# 7 5
# 5 4
# 9 9
# 1 1
# 0 0
# 2 0
# 1 0
# 4 5
# 3 3
# 1 1
# 5 5
# 2 2
# 4 5
# 9 7
# 5 5
# 9 9
# 3 3
# 10 9
# 2 1
# 2 3
# 2 0
# 2 0
# 5 3
# 0 0
# 5 4
# 3 3
# 5 5
# 0 0
# 4 3
# 5 5
# 6 5
# 8 7
# 2 4
# 1 0
# 6 5
# 0 0
# 2 1

# %% [markdown]
# # 获取评估指标,每个类别和总的召回率,精确率

# %%
def get_metrics(val_id2stem: dict[int, list[str]], pred_id2stem: dict[int, list[str]], eps: float = 1e-8) -> tuple[dict, dict[int, dict]]:
    """获取每个类别和总的评估指标

    Args:
        val_id2stem (dict[int, list[str]]):  val
        pred_id2stem (dict[int, list[str]]): pred
        eps (float): 防止除零. Default 1e-8

    Returns:
        tuple[dict, dict[int, dict]]:
            dict:               总指标
            dict[int, dict]:    各类别指标
    """
    total_val = 0       # val total
    total_pred = 0      # pred total
    total_detect = 0    # detect total
    result_for_cls = {} # 每个类别准确率
    for i in range(num_classes):
        # set在这里不为去重,仅仅为了求交集,差集
        val_stem_for_single_id: set = set(val_id2stem[i])   # 单一类别val图片名字
        pred_stem_for_single_id: set = set(pred_id2stem[i]) # 单一类别pred图片名字

        num_val = len(val_stem_for_single_id)
        total_val += num_val
        num_pred = len(pred_stem_for_single_id)
        total_pred += num_pred

        # 检测到的图片名字
        detect      = val_stem_for_single_id.intersection(pred_stem_for_single_id)
        num_detect  = len(detect)
        total_detect += num_detect
        # 没有检测到图片名字
        not_detect  = val_stem_for_single_id.difference(pred_stem_for_single_id)
        # 过度检测到图片名字
        over_detect = pred_stem_for_single_id.difference(val_stem_for_single_id)

        recall = num_detect / (num_val + eps)
        precision = num_detect / (num_pred + eps)
        f1_score = (2 * recall * precision) / (recall + precision + eps)

        # 按照类别id保存
        result_for_cls[i] = {
            "num_val": num_val,
            "num_pred": num_pred,
            "num_detect": num_detect,
            "recall": recall,
            "precision": precision,
            "f1_score": f1_score,
            "detect": detect,
            "not_detect": not_detect,
            "over_detect": over_detect,
        }

    recall = total_detect / total_val
    precision = total_detect / total_pred
    f1_score = (2 * recall * precision) / (recall + precision+ eps)

    total_result = {
        "num_val": total_val,
        "num_pred": total_pred,
        "num_detect": total_detect,
        "recall": recall,
        "precision": precision,
        "f1_score": f1_score,
    }

    return total_result, result_for_cls

# %%
total_result, result_for_cls = get_metrics(val_id2stem, pred_id2stem)
total_result
# Out:
# {'num_val': 362,
#  'num_pred': 323,
#  'num_detect': 287,
#  'recall': 0.7928176795580111,
#  'precision': 0.8885448916408669,
#  'f1_score': 0.8379557060006162}

# %%
result_for_cls
# Out:
# {0: {'num_val': 61,
#   'num_pred': 62,
#   'num_detect': 59,
#   'recall': 0.9672131147540983,
#   'precision': 0.9516129032258065,
#   'f1_score': 0.9593490935292447,
#   'detect': {'000000000036',
#    '000000000049',
#    '000000000061',
#    '000000000074',
#    '000000000077',
#    '000000000086',
#    '000000000109',
#    '000000000110',
#    '000000000113',
#    '000000000136',
#    '000000000149',
#    '000000000151',
#    '000000000165',
#    '000000000192',
#    '000000000201',
#    '000000000241',
#    '000000000257',
#    '000000000260',
#    '000000000294',
#    '000000000308',
#    '000000000315',
#    '000000000322',
#    '000000000326',
#    '000000000328',
#    '000000000338',
#    '000000000357',
#    '000000000360',
#    '000000000368',
#    '000000000370',
#    '000000000382',
#    '000000000389',
#    '000000000395',
#    '000000000397',
#    '000000000415',
#    '000000000419',
#    '000000000428',
#    '000000000431',
#    '000000000436',
#    '000000000443',
#    '000000000446',
#    '000000000459',
#    '000000000474',
#    '000000000488',
#    '000000000510',
#    '000000000520',
#    '000000000529',
#    '000000000531',
#    '000000000532',
#    '000000000536',
#    '000000000542',
#    '000000000544',
#    '000000000564',
#    '000000000569',
#    '000000000572',
#    '000000000589',
#    '000000000623',
#    '000000000625',
#    '000000000634',
#    '000000000641'},
#   'not_detect': {'000000000127', '000000000471'},
#   'over_detect': {'000000000208', '000000000247', '000000000387'}},
#  1: {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.6666661666670417,
#   'detect': {'000000000074', '000000000641'},
#   'not_detect': {'000000000531'},
#   'over_detect': {'000000000086'}},
#  2: {'num_val': 12,
#   'num_pred': 10,
#   'num_detect': 9,
#   'recall': 0.75,
#   'precision': 0.9,
#   'f1_score': 0.8181813223143503,
#   'detect': {'000000000064',
#    '000000000071',
#    '000000000094',
#    '000000000247',
#    '000000000260',
#    '000000000307',
#    '000000000359',
#    '000000000419',
#    '000000000540'},
#   'not_detect': {'000000000149', '000000000328', '000000000650'},
#   'over_detect': {'000000000074'}},
#  3: {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.75,
#   'precision': 0.75,
#   'f1_score': 0.7499995000003333,
#   'detect': {'000000000073', '000000000529', '000000000629'},
#   'not_detect': {'000000000086'},
#   'over_detect': {'000000000257'}},
#  4: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000081',
#    '000000000247',
#    '000000000472',
#    '000000000540',
#    '000000000542'},
#   'not_detect': set(),
#   'over_detect': set()},
#  5: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 0.8,
#   'f1_score': 0.7999995000003126,
#   'detect': {'000000000260', '000000000471', '000000000532', '000000000641'},
#   'not_detect': {'000000000540'},
#   'over_detect': {'000000000257'}},
#  6: {'num_val': 3,
#   'num_pred': 2,
#   'num_detect': 1,
#   'recall': 0.3333333333333333,
#   'precision': 0.5,
#   'f1_score': 0.399999520000576,
#   'detect': {'000000000071'},
#   'not_detect': {'000000000151', '000000000349'},
#   'over_detect': {'000000000400'}},
#  7: {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 1.0,
#   'f1_score': 0.8888883950620028,
#   'detect': {'000000000064', '000000000094', '000000000257', '000000000540'},
#   'not_detect': {'000000000071'},
#   'over_detect': set()},
#  8: {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186,
#   'detect': {'000000000404'},
#   'not_detect': {'000000000400'},
#   'over_detect': set()},
#  9: {'num_val': 4,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186,
#   'detect': {'000000000257', '000000000359'},
#   'not_detect': {'000000000510', '000000000540'},
#   'over_detect': set()},
#  10: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  11: {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000064', '000000000151'},
#   'not_detect': set(),
#   'over_detect': set()},
#  12: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  13: {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.75,
#   'f1_score': 0.666666172839872,
#   'detect': {'000000000109', '000000000127', '000000000510'},
#   'not_detect': {'000000000328', '000000000623'},
#   'over_detect': {'000000000569'}},
#  14: {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000143', '000000000520'},
#   'not_detect': set(),
#   'over_detect': set()},
#  15: {'num_val': 4,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.8,
#   'f1_score': 0.8888883950620028,
#   'detect': {'000000000443', '000000000575', '000000000599', '000000000650'},
#   'not_detect': set(),
#   'over_detect': {'000000000446'}},
#  16: {'num_val': 9,
#   'num_pred': 7,
#   'num_detect': 7,
#   'recall': 0.7777777777777778,
#   'precision': 1.0,
#   'f1_score': 0.8749995078127769,
#   'detect': {'000000000042',
#    '000000000074',
#    '000000000307',
#    '000000000309',
#    '000000000400',
#    '000000000490',
#    '000000000581'},
#   'not_detect': {'000000000109', '000000000394'},
#   'over_detect': set()},
#  17: {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000049'},
#   'not_detect': set(),
#   'over_detect': set()},
#  18: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  19: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  20: {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000061', '000000000263', '000000000312', '000000000597'},
#   'not_detect': set(),
#   'over_detect': set()},
#  21: {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000502'},
#   'not_detect': set(),
#   'over_detect': set()},
#  22: {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000034', '000000000154'},
#   'not_detect': set(),
#   'over_detect': set()},
#  23: {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000025', '000000000072', '000000000136', '000000000144'},
#   'not_detect': set(),
#   'over_detect': set()},
#  24: {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000257', '000000000328', '000000000382', '000000000389'},
#   'not_detect': set(),
#   'over_detect': set()},
#  25: {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000036', '000000000127', '000000000308', '000000000315'},
#   'not_detect': set(),
#   'over_detect': set()},
#  26: {'num_val': 9,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 0.3333333333333333,
#   'precision': 1.0,
#   'f1_score': 0.4999996250002813,
#   'detect': {'000000000241', '000000000315', '000000000536'},
#   'not_detect': {'000000000086',
#    '000000000127',
#    '000000000257',
#    '000000000338',
#    '000000000532',
#    '000000000542'},
#   'over_detect': set()},
#  27: {'num_val': 6,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.6666666666666666,
#   'precision': 1.0,
#   'f1_score': 0.7999995200002881,
#   'detect': {'000000000165', '000000000328', '000000000389', '000000000459'},
#   'not_detect': {'000000000428', '000000000542'},
#   'over_detect': set()},
#  28: {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000260', '000000000572'},
#   'not_detect': set(),
#   'over_detect': set()},
#  29: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000307',
#    '000000000322',
#    '000000000394',
#    '000000000589',
#    '000000000625'},
#   'not_detect': set(),
#   'over_detect': set()},
#  30: {'num_val': 1,
#   'num_pred': 2,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 0.5,
#   'f1_score': 0.6666662222225186,
#   'detect': {'000000000382'},
#   'not_detect': set(),
#   'over_detect': {'000000000201'}},
#  31: {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186,
#   'detect': {'000000000201'},
#   'not_detect': {'000000000360'},
#   'over_detect': set()},
#  32: {'num_val': 6,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.6666666666666666,
#   'precision': 1.0,
#   'f1_score': 0.7999995200002881,
#   'detect': {'000000000368', '000000000431', '000000000488', '000000000544'},
#   'not_detect': {'000000000419', '000000000531'},
#   'over_detect': set()},
#  33: {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000149', '000000000569'},
#   'not_detect': set(),
#   'over_detect': set()},
#  34: {'num_val': 4,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 0.75,
#   'precision': 1.0,
#   'f1_score': 0.8571423673472187,
#   'detect': {'000000000192', '000000000357', '000000000488'},
#   'not_detect': {'000000000544'},
#   'over_detect': set()},
#  35: {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.75,
#   'precision': 0.75,
#   'f1_score': 0.7499995000003333,
#   'detect': {'000000000474', '000000000488', '000000000544'},
#   'not_detect': {'000000000357'},
#   'over_detect': {'000000000192'}},
#  36: {'num_val': 3,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 1.0,
#   'f1_score': 0.7999995200002881,
#   'detect': {'000000000490', '000000000634'},
#   'not_detect': {'000000000077'},
#   'over_detect': set()},
#  37: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  38: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000415',
#    '000000000419',
#    '000000000431',
#    '000000000531',
#    '000000000564'},
#   'not_detect': set(),
#   'over_detect': set()},
#  39: {'num_val': 6,
#   'num_pred': 8,
#   'num_detect': 5,
#   'recall': 0.8333333333333334,
#   'precision': 0.625,
#   'f1_score': 0.7142852244901318,
#   'detect': {'000000000142',
#    '000000000164',
#    '000000000241',
#    '000000000283',
#    '000000000643'},
#   'not_detect': {'000000000486'},
#   'over_detect': {'000000000138', '000000000436', '000000000450'}},
#  40: {'num_val': 5,
#   'num_pred': 6,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 0.8333333333333334,
#   'f1_score': 0.909090413223411,
#   'detect': {'000000000164',
#    '000000000283',
#    '000000000308',
#    '000000000326',
#    '000000000450'},
#   'not_detect': set(),
#   'over_detect': {'000000000428'}},
#  41: {'num_val': 10,
#   'num_pred': 9,
#   'num_detect': 8,
#   'recall': 0.8,
#   'precision': 0.8888888888888888,
#   'f1_score': 0.8421047645432316,
#   'detect': {'000000000110',
#    '000000000113',
#    '000000000127',
#    '000000000164',
#    '000000000241',
#    '000000000332',
#    '000000000450',
#    '000000000605'},
#   'not_detect': {'000000000397', '000000000562'},
#   'over_detect': {'000000000590'}},
#  42: {'num_val': 6,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.3333333333333333,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.4444440000004445,
#   'detect': {'000000000092', '000000000196'},
#   'not_detect': {'000000000110',
#    '000000000294',
#    '000000000332',
#    '000000000397'},
#   'over_detect': {'000000000194'}},
#  43: {'num_val': 7,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 0.7142857142857143,
#   'precision': 1.0,
#   'f1_score': 0.8333328472225058,
#   'detect': {'000000000089',
#    '000000000110',
#    '000000000113',
#    '000000000127',
#    '000000000294'},
#   'not_detect': {'000000000194', '000000000486'},
#   'over_detect': set()},
#  44: {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 1.0,
#   'f1_score': 0.8888883950620028,
#   'detect': {'000000000127', '000000000196', '000000000294', '000000000605'},
#   'not_detect': {'000000000584'},
#   'over_detect': set()},
#  45: {'num_val': 9,
#   'num_pred': 9,
#   'num_detect': 8,
#   'recall': 0.8888888888888888,
#   'precision': 0.8888888888888888,
#   'f1_score': 0.8888883888891702,
#   'detect': {'000000000009',
#    '000000000138',
#    '000000000164',
#    '000000000196',
#    '000000000332',
#    '000000000486',
#    '000000000584',
#    '000000000643'},
#   'not_detect': {'000000000590'},
#   'over_detect': {'000000000338'}},
#  46: {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000142'},
#   'not_detect': set(),
#   'over_detect': set()},
#  47: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  48: {'num_val': 2,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': {'000000000142', '000000000321'},
#   'over_detect': set()},
#  49: {'num_val': 1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': {'000000000009'},
#   'over_detect': set()},
#  50: {'num_val': 4,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.8,
#   'f1_score': 0.8888883950620028,
#   'detect': {'000000000009', '000000000196', '000000000370', '000000000584'},
#   'not_detect': set(),
#   'over_detect': {'000000000194'}},
#  51: {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000196', '000000000332', '000000000584'},
#   'not_detect': set(),
#   'over_detect': set()},
#  52: {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000321'},
#   'not_detect': set(),
#   'over_detect': set()},
#  53: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000110',
#    '000000000194',
#    '000000000397',
#    '000000000450',
#    '000000000620'},
#   'not_detect': set(),
#   'over_detect': set()},
#  54: {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000436', '000000000438'},
#   'not_detect': set(),
#   'over_detect': set()},
#  55: {'num_val': 4,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.8,
#   'f1_score': 0.8888883950620028,
#   'detect': {'000000000092', '000000000113', '000000000127', '000000000428'},
#   'not_detect': set(),
#   'over_detect': {'000000000605'}},
#  56: {'num_val': 9,
#   'num_pred': 7,
#   'num_detect': 7,
#   'recall': 0.7777777777777778,
#   'precision': 1.0,
#   'f1_score': 0.8749995078127769,
#   'detect': {'000000000110',
#    '000000000113',
#    '000000000164',
#    '000000000283',
#    '000000000315',
#    '000000000397',
#    '000000000564'},
#   'not_detect': {'000000000536', '000000000623'},
#   'over_detect': set()},
#  57: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.6,
#   'f1_score': 0.5999995000004167,
#   'detect': {'000000000241', '000000000384', '000000000599'},
#   'not_detect': {'000000000443', '000000000446'},
#   'over_detect': {'000000000133', '000000000138'}},
#  58: {'num_val': 9,
#   'num_pred': 9,
#   'num_detect': 8,
#   'recall': 0.8888888888888888,
#   'precision': 0.8888888888888888,
#   'f1_score': 0.8888883888891702,
#   'detect': {'000000000049',
#    '000000000127',
#    '000000000138',
#    '000000000241',
#    '000000000349',
#    '000000000446',
#    '000000000560',
#    '000000000599'},
#   'not_detect': {'000000000030'},
#   'over_detect': {'000000000308'}},
#  59: {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.6666661666670417,
#   'detect': {'000000000133', '000000000514'},
#   'not_detect': {'000000000612'},
#   'over_detect': {'000000000164'}},
#  60: {'num_val': 10,
#   'num_pred': 9,
#   'num_detect': 6,
#   'recall': 0.6,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.6315784487538563,
#   'detect': {'000000000110',
#    '000000000113',
#    '000000000127',
#    '000000000196',
#    '000000000283',
#    '000000000605'},
#   'not_detect': {'000000000142',
#    '000000000164',
#    '000000000397',
#    '000000000450'},
#   'over_detect': {'000000000009', '000000000308', '000000000321'}},
#  61: {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186,
#   'detect': {'000000000636'},
#   'not_detect': {'000000000560'},
#   'over_detect': set()},
#  62: {'num_val': 2,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.7999995200002881,
#   'detect': {'000000000595', '000000000643'},
#   'not_detect': set(),
#   'over_detect': {'000000000294'}},
#  63: {'num_val': 2,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': {'000000000384', '000000000387'},
#   'over_detect': set()},
#  64: {'num_val': 2,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': {'000000000384', '000000000643'},
#   'over_detect': set()},
#  65: {'num_val': 5,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 1.0,
#   'f1_score': 0.749999531250293,
#   'detect': {'000000000241', '000000000443', '000000000599'},
#   'not_detect': {'000000000384', '000000000446'},
#   'over_detect': set()},
#  66: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  67: {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.75,
#   'f1_score': 0.666666172839872,
#   'detect': {'000000000328', '000000000395', '000000000536'},
#   'not_detect': {'000000000387', '000000000560'},
#   'over_detect': {'000000000443'}},
#  68: {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025,
#   'detect': {'000000000089', '000000000164', '000000000294'},
#   'not_detect': set(),
#   'over_detect': set()},
#  69: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.6,
#   'f1_score': 0.5999995000004167,
#   'detect': {'000000000089', '000000000138', '000000000338'},
#   'not_detect': {'000000000164', '000000000486'},
#   'over_detect': {'000000000294', '000000000620'}},
#  70: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  71: {'num_val': 4,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.5,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.571428081633073,
#   'detect': {'000000000560', '000000000590'},
#   'not_detect': {'000000000138', '000000000208'},
#   'over_detect': {'000000000338'}},
#  72: {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 0.8,
#   'f1_score': 0.7999995000003126,
#   'detect': {'000000000138', '000000000164', '000000000338', '000000000486'},
#   'not_detect': {'000000000620'},
#   'over_detect': {'000000000196'}},
#  73: {'num_val': 6,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 0.8333333333333334,
#   'precision': 1.0,
#   'f1_score': 0.909090413223411,
#   'detect': {'000000000127',
#    '000000000328',
#    '000000000384',
#    '000000000446',
#    '000000000643'},
#   'not_detect': {'000000000089'},
#   'over_detect': set()},
#  74: {'num_val': 8,
#   'num_pred': 7,
#   'num_detect': 7,
#   'recall': 0.875,
#   'precision': 1.0,
#   'f1_score': 0.933332835555821,
#   'detect': {'000000000064',
#    '000000000078',
#    '000000000138',
#    '000000000294',
#    '000000000338',
#    '000000000384',
#    '000000000626'},
#   'not_detect': {'000000000308'},
#   'over_detect': set()},
#  75: {'num_val': 2,
#   'num_pred': 4,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 0.5,
#   'f1_score': 0.6666662222225186,
#   'detect': {'000000000030', '000000000138'},
#   'not_detect': set(),
#   'over_detect': {'000000000078', '000000000612'}},
#  76: {'num_val': 1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': {'000000000165'},
#   'over_detect': set()},
#  77: {'num_val': 6,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 0.8333333333333334,
#   'precision': 1.0,
#   'f1_score': 0.909090413223411,
#   'detect': {'000000000309',
#    '000000000491',
#    '000000000612',
#    '000000000623',
#    '000000000643'},
#   'not_detect': {'000000000133'},
#   'over_detect': set()},
#  78: {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0,
#   'detect': set(),
#   'not_detect': set(),
#   'over_detect': set()},
#  79: {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186,
#   'detect': {'000000000562'},
#   'not_detect': {'000000000208'},
#   'over_detect': set()}}

# %% [markdown]
# # load label name

# %%
with open(label_path, 'r', encoding='utf-8') as f:
    dataset = yaml.safe_load(f)
names = dataset["names"]
names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
name2acc = {}
for name, acc_cls in zip(names.values(), result_for_cls.values()):
    name2acc[name] = {
        "num_val": acc_cls["num_val"],
        "num_pred": acc_cls["num_pred"],
        "num_detect": acc_cls["num_detect"],
        "recall": acc_cls["recall"],
        "precision": acc_cls["precision"],
        "f1_score": acc_cls["f1_score"],
    }
name2acc
# Out:
# {'person': {'num_val': 61,
#   'num_pred': 62,
#   'num_detect': 59,
#   'recall': 0.9672131147540983,
#   'precision': 0.9516129032258065,
#   'f1_score': 0.9593490935292447},
#  'bicycle': {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.6666661666670417},
#  'car': {'num_val': 12,
#   'num_pred': 10,
#   'num_detect': 9,
#   'recall': 0.75,
#   'precision': 0.9,
#   'f1_score': 0.8181813223143503},
#  'motorcycle': {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.75,
#   'precision': 0.75,
#   'f1_score': 0.7499995000003333},
#  'airplane': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'bus': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 0.8,
#   'f1_score': 0.7999995000003126},
#  'train': {'num_val': 3,
#   'num_pred': 2,
#   'num_detect': 1,
#   'recall': 0.3333333333333333,
#   'precision': 0.5,
#   'f1_score': 0.399999520000576},
#  'truck': {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 1.0,
#   'f1_score': 0.8888883950620028},
#  'boat': {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186},
#  'traffic light': {'num_val': 4,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186},
#  'fire hydrant': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'stop sign': {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'parking meter': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'bench': {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.75,
#   'f1_score': 0.666666172839872},
#  'bird': {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'cat': {'num_val': 4,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.8,
#   'f1_score': 0.8888883950620028},
#  'dog': {'num_val': 9,
#   'num_pred': 7,
#   'num_detect': 7,
#   'recall': 0.7777777777777778,
#   'precision': 1.0,
#   'f1_score': 0.8749995078127769},
#  'horse': {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'sheep': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'cow': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'elephant': {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'bear': {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'zebra': {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'giraffe': {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'backpack': {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'umbrella': {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'handbag': {'num_val': 9,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 0.3333333333333333,
#   'precision': 1.0,
#   'f1_score': 0.4999996250002813},
#  'tie': {'num_val': 6,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.6666666666666666,
#   'precision': 1.0,
#   'f1_score': 0.7999995200002881},
#  'suitcase': {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'frisbee': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'skis': {'num_val': 1,
#   'num_pred': 2,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 0.5,
#   'f1_score': 0.6666662222225186},
#  'snowboard': {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186},
#  'sports ball': {'num_val': 6,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.6666666666666666,
#   'precision': 1.0,
#   'f1_score': 0.7999995200002881},
#  'kite': {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'baseball bat': {'num_val': 4,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 0.75,
#   'precision': 1.0,
#   'f1_score': 0.8571423673472187},
#  'baseball glove': {'num_val': 4,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.75,
#   'precision': 0.75,
#   'f1_score': 0.7499995000003333},
#  'skateboard': {'num_val': 3,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 1.0,
#   'f1_score': 0.7999995200002881},
#  'surfboard': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'tennis racket': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'bottle': {'num_val': 6,
#   'num_pred': 8,
#   'num_detect': 5,
#   'recall': 0.8333333333333334,
#   'precision': 0.625,
#   'f1_score': 0.7142852244901318},
#  'wine glass': {'num_val': 5,
#   'num_pred': 6,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 0.8333333333333334,
#   'f1_score': 0.909090413223411},
#  'cup': {'num_val': 10,
#   'num_pred': 9,
#   'num_detect': 8,
#   'recall': 0.8,
#   'precision': 0.8888888888888888,
#   'f1_score': 0.8421047645432316},
#  'fork': {'num_val': 6,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.3333333333333333,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.4444440000004445},
#  'knife': {'num_val': 7,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 0.7142857142857143,
#   'precision': 1.0,
#   'f1_score': 0.8333328472225058},
#  'spoon': {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 1.0,
#   'f1_score': 0.8888883950620028},
#  'bowl': {'num_val': 9,
#   'num_pred': 9,
#   'num_detect': 8,
#   'recall': 0.8888888888888888,
#   'precision': 0.8888888888888888,
#   'f1_score': 0.8888883888891702},
#  'banana': {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'apple': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'sandwich': {'num_val': 2,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'orange': {'num_val': 1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'broccoli': {'num_val': 4,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.8,
#   'f1_score': 0.8888883950620028},
#  'carrot': {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'hot dog': {'num_val': 1,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'pizza': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'donut': {'num_val': 2,
#   'num_pred': 2,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'cake': {'num_val': 4,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 1.0,
#   'precision': 0.8,
#   'f1_score': 0.8888883950620028},
#  'chair': {'num_val': 9,
#   'num_pred': 7,
#   'num_detect': 7,
#   'recall': 0.7777777777777778,
#   'precision': 1.0,
#   'f1_score': 0.8749995078127769},
#  'couch': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.6,
#   'f1_score': 0.5999995000004167},
#  'potted plant': {'num_val': 9,
#   'num_pred': 9,
#   'num_detect': 8,
#   'recall': 0.8888888888888888,
#   'precision': 0.8888888888888888,
#   'f1_score': 0.8888883888891702},
#  'bed': {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.6666666666666666,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.6666661666670417},
#  'dining table': {'num_val': 10,
#   'num_pred': 9,
#   'num_detect': 6,
#   'recall': 0.6,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.6315784487538563},
#  'toilet': {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186},
#  'tv': {'num_val': 2,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.7999995200002881},
#  'laptop': {'num_val': 2,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'mouse': {'num_val': 2,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'remote': {'num_val': 5,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 1.0,
#   'f1_score': 0.749999531250293},
#  'keyboard': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'cell phone': {'num_val': 5,
#   'num_pred': 4,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.75,
#   'f1_score': 0.666666172839872},
#  'microwave': {'num_val': 3,
#   'num_pred': 3,
#   'num_detect': 3,
#   'recall': 1.0,
#   'precision': 1.0,
#   'f1_score': 0.99999950000025},
#  'oven': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 3,
#   'recall': 0.6,
#   'precision': 0.6,
#   'f1_score': 0.5999995000004167},
#  'toaster': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'sink': {'num_val': 4,
#   'num_pred': 3,
#   'num_detect': 2,
#   'recall': 0.5,
#   'precision': 0.6666666666666666,
#   'f1_score': 0.571428081633073},
#  'refrigerator': {'num_val': 5,
#   'num_pred': 5,
#   'num_detect': 4,
#   'recall': 0.8,
#   'precision': 0.8,
#   'f1_score': 0.7999995000003126},
#  'book': {'num_val': 6,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 0.8333333333333334,
#   'precision': 1.0,
#   'f1_score': 0.909090413223411},
#  'clock': {'num_val': 8,
#   'num_pred': 7,
#   'num_detect': 7,
#   'recall': 0.875,
#   'precision': 1.0,
#   'f1_score': 0.933332835555821},
#  'vase': {'num_val': 2,
#   'num_pred': 4,
#   'num_detect': 2,
#   'recall': 1.0,
#   'precision': 0.5,
#   'f1_score': 0.6666662222225186},
#  'scissors': {'num_val': 1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'teddy bear': {'num_val': 6,
#   'num_pred': 5,
#   'num_detect': 5,
#   'recall': 0.8333333333333334,
#   'precision': 1.0,
#   'f1_score': 0.909090413223411},
#  'hair drier': {'num_val': 0.1,
#   'num_pred': 0.1,
#   'num_detect': 0,
#   'recall': 0.0,
#   'precision': 0.0,
#   'f1_score': 0.0},
#  'toothbrush': {'num_val': 2,
#   'num_pred': 1,
#   'num_detect': 1,
#   'recall': 0.5,
#   'precision': 1.0,
#   'f1_score': 0.6666662222225186}}

# %%
total_result
# Out:
# {'num_val': 362,
#  'num_pred': 323,
#  'num_detect': 287,
#  'recall': 0.7928176795580111,
#  'precision': 0.8885448916408669,
#  'f1_score': 0.8379557060006162}

# %%
name2acc["total"] = total_result

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(name2acc, index=["num_val", "num_pred", "num_detect", "recall", "precision", "f1_score"]).T
df
# Out:
#             num_val  num_pred  num_detect    recall  precision  f1_score
# person         61.0      62.0        59.0  0.967213   0.951613  0.959349
# bicycle         3.0       3.0         2.0  0.666667   0.666667  0.666666
# car            12.0      10.0         9.0  0.750000   0.900000  0.818181
# motorcycle      4.0       4.0         3.0  0.750000   0.750000  0.750000
# airplane        5.0       5.0         5.0  1.000000   1.000000  1.000000
# ...             ...       ...         ...       ...        ...       ...
# scissors        1.0       0.1         0.0  0.000000   0.000000  0.000000
# teddy bear      6.0       5.0         5.0  0.833333   1.000000  0.909090
# hair drier      0.1       0.1         0.0  0.000000   0.000000  0.000000
# toothbrush      2.0       1.0         1.0  0.500000   1.000000  0.666666
# total         362.0     323.0       287.0  0.792818   0.888545  0.837956
#
# [81 rows x 6 columns]

# %%
# df.to_excel("result.xlsx")

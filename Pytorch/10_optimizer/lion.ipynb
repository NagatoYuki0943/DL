# %%
from torch import nn, optim
from lion_pytorch import Lion
import matplotlib.pyplot as plt

# %%
from IPython.display import clear_output

# !pip install lion-pytorch

clear_output()

# %%
net = nn.Linear(10, 1)

# %%
optimizer = Lion(
    net.parameters(),
    lr=0.0001,
    betas=(0.9, 0.99),
    weight_decay=1e-2,
    use_triton=False,
)
optimizer
# Out:
# Lion (
# Parameter Group 0
#     betas: (0.9, 0.99)
#     lr: 0.0001
#     weight_decay: 0.01
# )

# %%
optimizer.state_dict()
# Out:
# {'state': {},
#  'param_groups': [{'lr': 0.0001,
#    'betas': (0.9, 0.99),
#    'weight_decay': 0.01,
#    'params': [0, 1]}]}

# %%
EPOCHS = 100
LR = 0.0001

# %%
lr_sche = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=LR*0.1)

# %%
lr_sche.state_dict()
# Out:
# {'T_max': 100,
#  'eta_min': 1e-05,
#  'base_lrs': [0.0001],
#  'last_epoch': 0,
#  'verbose': False,
#  '_step_count': 1,
#  '_get_lr_called_within_step': False,
#  '_last_lr': [0.0001]}

# %%
def get_lr(optimizer):
    return optimizer.state_dict()['param_groups'][0]['lr']

# %%
lrs = []
for _ in range(EPOCHS):
    print("lr =", optimizer.state_dict()['param_groups'][0]['lr'])
    optimizer.zero_grad()
    ...
    optimizer.step()
    lrs.append(get_lr(optimizer))
    lr_sche.step()
# Out:
# lr = 0.0001
# lr = 9.997779521645793e-05
# lr = 9.991120277927223e-05
# lr = 9.980028840713861e-05
# lr = 9.964516155915153e-05
# lr = 9.944597532678122e-05
# lr = 9.920292628279102e-05
# lr = 9.891625428724366e-05
# lr = 9.858624225078842e-05
# lr = 9.821321585546247e-05
# lr = 9.779754323328194e-05
# lr = 9.733963460294018e-05
# lr = 9.683994186497135e-05
# lr = 9.629895815577918e-05
# lr = 9.571721736097092e-05
# lr = 9.509529358847659e-05
# lr = 9.44338006019739e-05
# lr = 9.373339121517751e-05
# lr = 9.299475664759073e-05
# lr = 9.221862584235533e-05
# lr = 9.140576474687269e-05
# lr = 9.055697555690612e-05
# lr = 8.967309592491057e-05
# lr = 8.875499813337074e-05
# lr = 8.780358823396357e-05
# lr = 8.681980515339469e-05
# lr = 8.580461976679105e-05
# lr = 8.47590339395644e-05
# lr = 8.36840795386911e-05
# lr = 8.258081741438401e-05
# lr = 8.145033635316136e-05
# lr = 8.029375200334595e-05
# lr = 7.911220577405491e-05
# lr = 7.790686370876678e-05
# lr = 7.667891533457724e-05
# lr = 7.542957248827967e-05
# lr = 7.416006812042833e-05
# lr = 7.287165507856519e-05
# lr = 7.156560487081058e-05
# lr = 7.024320641103819e-05
# lr = 6.890576474687271e-05
# lr = 6.75545997717654e-05
# lr = 6.619104492241853e-05
# lr = 6.48164458628445e-05
# lr = 6.34321591563577e-05
# lr = 6.203955092681049e-05
# lr = 6.063999551039379e-05
# lr = 5.9234874099333234e-05
# lr = 5.782557337881919e-05
# lr = 5.641348415851586e-05
# lr = 5.500000000000008e-05
# lr = 5.3586515841484306e-05
# lr = 5.2174426621180974e-05
# lr = 5.0765125900666926e-05
# lr = 4.936000448960638e-05
# lr = 4.7960449073189674e-05
# lr = 4.656784084364245e-05
# lr = 4.5183554137155654e-05
# lr = 4.380895507758159e-05
# lr = 4.244540022823474e-05
# lr = 4.109423525312743e-05
# lr = 3.975679358896194e-05
# lr = 3.843439512918955e-05
# lr = 3.7128344921434914e-05
# lr = 3.583993187957177e-05
# lr = 3.457042751172044e-05
# lr = 3.332108466542285e-05
# lr = 3.209313629123333e-05
# lr = 3.088779422594518e-05
# lr = 2.970624799665416e-05
# lr = 2.8549663646838757e-05
# lr = 2.7419182585616097e-05
# lr = 2.6315920461309e-05
# lr = 2.524096606043571e-05
# lr = 2.4195380233209042e-05
# lr = 2.3180194846605398e-05
# lr = 2.219641176603652e-05
# lr = 2.124500186662935e-05
# lr = 2.0326904075089513e-05
# lr = 1.9443024443093955e-05
# lr = 1.8594235253127392e-05
# lr = 1.7781374157644745e-05
# lr = 1.7005243352409347e-05
# lr = 1.6266608784822544e-05
# lr = 1.5566199398026153e-05
# lr = 1.4904706411523462e-05
# lr = 1.428278263902914e-05
# lr = 1.370104184422087e-05
# lr = 1.3160058135028698e-05
# lr = 1.2660365397059863e-05
# lr = 1.2202456766718098e-05
# lr = 1.1786784144537573e-05
# lr = 1.1413757749211612e-05
# lr = 1.1083745712756375e-05
# lr = 1.0797073717209012e-05
# lr = 1.0554024673218808e-05
# lr = 1.0354838440848503e-05
# lr = 1.0199711592861402e-05
# lr = 1.0088797220727781e-05
# lr = 1.002220478354208e-05

# %%
plt.plot(lrs)
plt.grid(True)
